# %% [markdown]
# <a href="https://colab.research.google.com/github/Puja-sah-aj/project/blob/main/titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('titanic_dataset.csv')

# %%
df.head()

# %%
sns.histplot(df['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.histplot(df['Age'],kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.histplot(df['Age'],kde=True,color='r')
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.distplot(df['Age'],kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df['Age'],kde=True,color='r')
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.lineplot(x=df['Name'],y=df['Age'])
# Out:
# <Axes: xlabel='Name', ylabel='Age'>

# %%
df=pd.read_excel('Covid cases in India.xlsx')

# %%
df.head()
# Out:
#    S. No. Name of State / UT  Total Confirmed cases (Indian National)  \
# 0       1     Andhra Pradesh                                       12
# 1       2       Chhattisgarh                                        6
# 2       3              Delhi                                       38
# 3       4            Gujarat                                       43
# 4       5            Haryana                                       16
#
#    Total Confirmed cases ( Foreign National )  Cured  Death
# 0                                           0      1      0
# 1                                           0      0      0
# 2                                           1      6      1
# 3                                           0      0      3
# 4                                          14     11      0

# %%
df.shape
# Out:
# (26, 6)

# %%
df.describe()
# Out:
#           S. No.  Total Confirmed cases (Indian National)  \
# count  26.000000                                26.000000
# mean   13.500000                                26.423077
# std     7.648529                                35.586709
# min     1.000000                                 1.000000
# 25%     7.250000                                 6.000000
# 50%    13.500000                                14.500000
# 75%    19.750000                                33.500000
# max    26.000000                               144.000000
#
#        Total Confirmed cases ( Foreign National )      Cured      Death
# count                                   26.000000  26.000000  26.000000
# mean                                     1.615385   2.461538   0.653846
# std                                      3.589729   4.420233   1.017539
# min                                      0.000000   0.000000   0.000000
# 25%                                      0.000000   0.000000   0.000000
# ...

# %%
df.drop('S. No.',axis=1,inplace=True)

# %%
df
# Out:
#    Name of State / UT  Total Confirmed cases (Indian National)  \
# 0      Andhra Pradesh                                       12
# 1        Chhattisgarh                                        6
# 2               Delhi                                       38
# 3             Gujarat                                       43
# 4             Haryana                                       16
# 5    Himachal Pradesh                                        4
# 6           Karnataka                                       20
# 7              Kerala                                      131
# 8      Madhya Pradesh                                       23
# 9         Maharashtra                                      144
# 10             Odisha                                        3
# 11         Puducherry                                        1
# 12             Punjab                                       29
# 13          Rajasthan                                       41
# ...

# %%
df.head()
# Out:
#   Name of State / UT  Total Confirmed cases (Indian National)  \
# 0     Andhra Pradesh                                       12
# 1       Chhattisgarh                                        6
# 2              Delhi                                       38
# 3            Gujarat                                       43
# 4            Haryana                                       16
#
#    Total Confirmed cases ( Foreign National )  Cured  Death
# 0                                           0      1      0
# 1                                           0      0      0
# 2                                           1      6      1
# 3                                           0      0      3
# 4                                          14     11      0

# %%
df['Total Confirmed cases (Indian National)']
# Out:
# 0      12
# 1       6
# 2      38
# 3      43
# 4      16
# 5       4
# 6      20
# 7     131
# 8      23
# 9     144
# 10      3
# 11      1
# 12     29
# 13     41
# 14     32
# 15     34
# 16      7
# 17     18
# 18     13
# 19     42
# 20      4
# 21     11
# 22      7
# 23      1
# 24      6
# 25      1
# Name: Total Confirmed cases (Indian National), dtype: int64

# %%
df['Total cases']=df['Total Confirmed cases (Indian National)']+df['Total Confirmed cases ( Foreign National )']

# %%
df
# Out:
#    Name of State / UT  Total Confirmed cases (Indian National)  \
# 0      Andhra Pradesh                                       12
# 1        Chhattisgarh                                        6
# 2               Delhi                                       38
# 3             Gujarat                                       43
# 4             Haryana                                       16
# 5    Himachal Pradesh                                        4
# 6           Karnataka                                       20
# 7              Kerala                                      131
# 8      Madhya Pradesh                                       23
# 9         Maharashtra                                      144
# 10             Odisha                                        3
# 11         Puducherry                                        1
# 12             Punjab                                       29
# 13          Rajasthan                                       41
# ...

# %%
df['Total cases'].sum()
# Out:
# 729

# %%
df['Total cases'].sum()
print('Total cases of covid-19 in India:',df['Total cases'].sum())
# Out:
# Total cases of covid-19 in India: 729

# %%
df.head(2)
# Out:
#   Name of State / UT  Total Confirmed cases (Indian National)  \
# 0     Andhra Pradesh                                       12
# 1       Chhattisgarh                                        6
#
#    Total Confirmed cases ( Foreign National )  Cured  Death  Total cases
# 0                                           0      1      0           12
# 1                                           0      0      0            6

# %%
#Active cases
df['Total Active']=df['Total cases']-df['Cured']-df['Death']

# %%
df['Total Active'].sum()
# Out:
# 648

# %%
df1=df[['Name of State / UT','Total cases','Cured','Death','Total Active']]

# %%
df1.head()
# Out:
#   Name of State / UT  Total cases  Cured  Death  Total Active
# 0     Andhra Pradesh           12      1      0            11
# 1       Chhattisgarh            6      0      0             6
# 2              Delhi           39      6      1            32
# 3            Gujarat           43      0      3            40
# 4            Haryana           30     11      0            19

# %%
#barplot seaborn
sns.barplot(x=df['Total cases'],y=df['Name of State / UT'])
# Out:
# <Axes: xlabel='Total cases', ylabel='Name of State / UT'>

# %%
sns.barplot(x=df['Total cases'],y=df['Death'])
# Out:
# <Axes: xlabel='Total cases', ylabel='Death'>

# %%
sns.barplot(x='Cured',y='Name of State / UT',data=df)
# Out:
# <Axes: xlabel='Cured', ylabel='Name of State / UT'>

# %%
sns.barplot(x='Cured',y='Name of State / UT',data=df)
plt.title('Covid-19 cured patients')
# Out:
# Text(0.5, 1.0, 'Covid-19 cured patients')

# %%
sns.scatterplot(x=df['Total cases'],y=df['Death'])
# Out:
# <Axes: xlabel='Total cases', ylabel='Death'>

# %%
sns.scatterplot(y=df['Total cases'],x=df['Name of State / UT'])
# Out:
# <Axes: xlabel='Name of State / UT', ylabel='Total cases'>

# %%
sns.scatterplot(x=df['Total cases'],y=df['Name of State / UT'])
# Out:
# <Axes: xlabel='Total cases', ylabel='Name of State / UT'>
